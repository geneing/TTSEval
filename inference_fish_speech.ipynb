# %% [markdown]
# # Fish Speech

# %% [markdown]
# ### For Windows User / win用户

# %%
# !chcp 65001

# %% [markdown]
# ### For Linux User / Linux 用户

# %%
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')

import os
import nltk

nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import glob
# Out:
# [nltk_data] Downloading package punkt to /home/eingerman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Prepare Model

# %%
# For Chinese users, you probably want to use mirror to accelerate downloading
# !set HF_ENDPOINT=https://hf-mirror.com
# !export HF_ENDPOINT=https://hf-mirror.com 

# !huggingface-cli download fishaudio/openaudio-s1-mini --local-dir checkpoints/openaudio-s1-mini/

# %% [markdown]
# ## WebUI Inference
#
# > You can use --compile to fuse CUDA kernels for faster inference (10x).

# %%
# !python tools/run_webui.py \
    --llama-checkpoint-path checkpoints/openaudio-s1-mini \
    --decoder-checkpoint-path checkpoints/openaudio-s1-mini/codec.pth \
    # --compile

# %% [markdown]
# ## Break-down CLI Inference

# %% [markdown]
# ### 1. Encode reference audio: / 从语音生成 prompt:
#
# You should get a `fake.npy` file.
#
# 你应该能得到一个 `fake.npy` 文件.

# %%
## Enter the path to the audio file here
src_audio = r"../outputs/kokoro/1.txt.wav"

# !python fish_speech/models/dac/inference.py \
    -i {src_audio} \
    --checkpoint-path "checkpoints/openaudio-s1-mini/codec.pth"

from IPython.display import Audio, display
audio = Audio(filename="fake.wav")
display(audio)
# Out:
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:05:42.152 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:05:42.152 | INFO     | __main__:main:75 - Processing in-place reconstruction of ../outputs/kokoro/1.txt.wav
# 2025-06-08 14:05:42.237 | INFO     | __main__:main:84 - Loaded audio with 10.05 seconds
# 2025-06-08 14:05:43.693 | INFO     | __main__:main:95 - Generated indices of shape torch.Size([10, 217])
# 2025-06-08 14:05:44.030 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 444416]), equivalent to 10.08 seconds from 217 features, features/second: 21.53
# 2025-06-08 14:05:44.051 | INFO     | __main__:main:119 - Saved audio to fake.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 2. Generate semantic tokens from text: / 从文本生成语义 token:
#
# > This command will create a codes_N file in the working directory, where N is an integer starting from 0.
#
# > You may want to use `--compile` to fuse CUDA kernels for faster inference (~30 tokens/second -> ~300 tokens/second).
#
# > 该命令会在工作目录下创建 codes_N 文件, 其中 N 是从 0 开始的整数.
#
# > 您可以使用 `--compile` 来融合 cuda 内核以实现更快的推理 (~30 tokens/秒 -> ~300 tokens/秒)

# %%
# with open("../inputs/2.txt", "r") as f:
#     text = f.read()
#     text = text.replace("\"", "\\""") #.replace("\n", " ")
#     print(text)
# text = "She sells seashells on the seashore. The shells she sells are seashells, I’m sure, so if she sells seashells on the seashore, then I’m sure she sells seashore shells."
for fname in glob.glob("../inputs/*.txt"):
    with open(fname, "r") as f:
        texts = f.read().strip()
        print(texts)
        #split text into sentences using nltk
        cmd = "sox "
        for i, text in enumerate(sent_tokenize(texts)):
            text = text.replace("\"", "\\""").replace("\n", " ")
            print(f"Processing text: {text}")
            # !python fish_speech/models/text2semantic/inference.py \
                --text "{text}" \
                --prompt-text "Expressive audiobook text" \
                --prompt-tokens "fake.npy" \
                --checkpoint-path "checkpoints/openaudio-s1-mini" \
                --num-samples 1 --compile
            # !python fish_speech/models/dac/inference.py \
                -i "temp/codes_0.npy" \
                --checkpoint-path "checkpoints/openaudio-s1-mini/codec.pth" \
                -o "temp/{i}.wav"
            cmd += f" temp/{i}.wav"
        cmd += f" ../outputs/fish-speech/{os.path.basename(fname)}.wav"
        print(cmd)
        # !{cmd}
# Out:
# Of all the problems which have been submitted to my friend, Mr. Sherlock Holmes, for solution during the years of our intimacy, there were only two which I was the means of introducing to his notice—that of Mr. Hatherley’s thumb, and that of Colonel Warburton’s madness.
# Of these the latter may have afforded a finer field for an acute and original observer, but the other was so strange in its inception and so dramatic in its details that it may be the more worthy of being placed upon record, even if it gave my friend fewer openings for those deductive methods of reasoning by which he achieved such remarkable results.
# The story has, I believe, been told more than once in the newspapers, but, like all such narratives, its effect is much less striking when set forth en bloc in a single half-column of print than when the facts slowly evolve before your own eyes, and the mystery clears gradually away as each new discovery furnishes a step which leads on to the complete truth.
# At the time the circumstances made a deep impression upon me, and the lapse of two years has hardly served to weaken the effect.
# It was in the summer of ’89, not long after my marriage, that the events occurred which I am now about to summarise.
# I had returned to civil practice and had finally abandoned Holmes in his Baker Street rooms, although I continually visited him and occasionally even persuaded him to forgo his Bohemian habits so far as to come and visit us.
# My practice had steadily increased, and as I happened to live at no very great distance from Paddington Station, I got a few patients from among the officials.
# One of these, whom I had cured of a painful and lingering disease, was never weary of advertising my virtues and of endeavouring to send me on every sufferer over whom he might have any influence.
# One morning, at a little before seven o’clock, I was awakened by the maid tapping at the door to announce that two men had come from Paddington and were waiting in the consulting-room.
# I dressed hurriedly, for I knew by experience that railway cases were seldom trivial, and hastened downstairs.
# As I descended, my old ally, the guard, came out of the room and closed the door tightly behind him.
# "I’ve got him here," he whispered, jerking his thumb over his shoulder; "he’s all right."
# "What is it, then?"
# I asked, for his manner suggested that it was some strange creature which he had caged up in my room.
# "It’s a new patient," he whispered.
# "I thought I’d bring him round myself; then he couldn’t slip away.
# There he is, all safe and sound.
# I must go now, Doctor; I have my dooties, just the same as you."
# And off he went, this trusty tout, without even giving me time to thank him.
# Processing text: Of all the problems which have been submitted to my friend, Mr. Sherlock Holmes, for solution during the years of our intimacy, there were only two which I was the means of introducing to his notice—that of Mr. Hatherley’s thumb, and that of Colonel Warburton’s madness.
# 2025-06-08 14:16:53.937 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:16:54.140 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:17:02.865 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:17:05.695 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:17:05.695 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:17:05.695 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:17:06.590 | INFO     | __main__:main:607 - Time to load model: 12.65 seconds
# 2025-06-08 14:17:06.602 | INFO     | __main__:generate_long:395 - Encoded text: Of all the problems which have been submitted to my friend, Mr. Sherlock Holmes, for solution during the years of our intimacy, there were only two which I was the means of introducing to his notice—that of Mr. Hatherley's thumb, and that of Colonel Warburton's madness.
# 2025-06-08 14:17:06.603 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   4%|█▍                                      | 293/7906 [00:16<07:07, 17.81it/s]
# 2025-06-08 14:17:23.801 | INFO     | __main__:generate_long:442 - Compilation time: 17.20 seconds
# 2025-06-08 14:17:23.802 | INFO     | __main__:generate_long:451 - Generated 295 tokens in 17.20 seconds, 17.15 tokens/sec
# 2025-06-08 14:17:23.802 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 14.75 GB/s
# 2025-06-08 14:17:23.802 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:17:23.814 | INFO     | __main__:main:640 - Sampled text: Of all the problems which have been submitted to my friend, Mr. Sherlock Holmes, for solution during the years of our intimacy, there were only two which I was the means of introducing to his notice—that of Mr. Hatherley's thumb, and that of Colonel Warburton's madness.
# 2025-06-08 14:17:23.816 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:17:23.816 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:17:36.891 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:17:36.891 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:17:37.817 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 602112]), equivalent to 13.65 seconds from 294 features, features/second: 21.53
# 2025-06-08 14:17:37.836 | INFO     | __main__:main:119 - Saved audio to temp/0.wav
# Processing text: Of these the latter may have afforded a finer field for an acute and original observer, but the other was so strange in its inception and so dramatic in its details that it may be the more worthy of being placed upon record, even if it gave my friend fewer openings for those deductive methods of reasoning by which he achieved such remarkable results.
# 2025-06-08 14:17:42.567 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:17:42.799 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:17:50.004 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:17:51.295 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:17:51.296 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:17:51.296 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:17:51.952 | INFO     | __main__:main:607 - Time to load model: 9.38 seconds
# 2025-06-08 14:17:51.963 | INFO     | __main__:generate_long:395 - Encoded text: Of these the latter may have afforded a finer field for an acute and original observer, but the other was so strange in its inception and so dramatic in its details that it may be the more worthy of being placed upon record,
# 2025-06-08 14:17:51.965 | INFO     | __main__:generate_long:395 - Encoded text: even if it gave my friend fewer openings for those deductive methods of reasoning by which he achieved such remarkable results.
# 2025-06-08 14:17:51.965 | INFO     | __main__:generate_long:413 - Generating sentence 1/2 of sample 1/1
#   3%|█▎                                      | 267/7922 [00:16<07:44, 16.47it/s]
# 2025-06-08 14:18:08.832 | INFO     | __main__:generate_long:442 - Compilation time: 16.87 seconds
# 2025-06-08 14:18:08.832 | INFO     | __main__:generate_long:451 - Generated 269 tokens in 16.87 seconds, 15.95 tokens/sec
# 2025-06-08 14:18:08.832 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 13.72 GB/s
# 2025-06-08 14:18:08.832 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:18:08.842 | INFO     | __main__:main:640 - Sampled text: Of these the latter may have afforded a finer field for an acute and original observer, but the other was so strange in its inception and so dramatic in its details that it may be the more worthy of being placed upon record,
# 2025-06-08 14:18:08.843 | INFO     | __main__:generate_long:413 - Generating sentence 2/2 of sample 1/1
#   2%|▋                                       | 147/7944 [00:02<02:14, 57.81it/s]
# 2025-06-08 14:18:11.541 | INFO     | __main__:generate_long:451 - Generated 149 tokens in 2.70 seconds, 55.23 tokens/sec
# 2025-06-08 14:18:11.541 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 47.50 GB/s
# 2025-06-08 14:18:11.541 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.86 GB
# 2025-06-08 14:18:11.542 | INFO     | __main__:main:640 - Sampled text: even if it gave my friend fewer openings for those deductive methods of reasoning by which he achieved such remarkable results.
# 2025-06-08 14:18:11.543 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:18:11.543 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:18:24.436 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:18:24.436 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:18:25.605 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 851968]), equivalent to 19.32 seconds from 416 features, features/second: 21.53
# 2025-06-08 14:18:25.614 | INFO     | __main__:main:119 - Saved audio to temp/1.wav
# Processing text: The story has, I believe, been told more than once in the newspapers, but, like all such narratives, its effect is much less striking when set forth en bloc in a single half-column of print than when the facts slowly evolve before your own eyes, and the mystery clears gradually away as each new discovery furnishes a step which leads on to the complete truth.
# 2025-06-08 14:18:30.489 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:18:30.767 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:18:39.629 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:18:41.115 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:18:41.115 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:18:41.115 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:18:41.998 | INFO     | __main__:main:607 - Time to load model: 11.51 seconds
# 2025-06-08 14:18:42.011 | INFO     | __main__:generate_long:395 - Encoded text: The story has, I believe, been told more than once in the newspapers, but, like all such narratives, its effect is much less striking when set forth en bloc in a single half-column of print than when the facts slowly evolve before your own eyes,
# 2025-06-08 14:18:42.015 | INFO     | __main__:generate_long:395 - Encoded text: and the mystery clears gradually away as each new discovery furnishes a step which leads on to the complete truth.
# 2025-06-08 14:18:42.015 | INFO     | __main__:generate_long:413 - Generating sentence 1/2 of sample 1/1
#   4%|█▍                                      | 285/7914 [00:19<08:37, 14.76it/s]
# 2025-06-08 14:19:02.392 | INFO     | __main__:generate_long:442 - Compilation time: 20.38 seconds
# 2025-06-08 14:19:02.392 | INFO     | __main__:generate_long:451 - Generated 287 tokens in 20.38 seconds, 14.08 tokens/sec
# 2025-06-08 14:19:02.392 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 12.12 GB/s
# 2025-06-08 14:19:02.393 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:19:02.408 | INFO     | __main__:main:640 - Sampled text: The story has, I believe, been told more than once in the newspapers, but, like all such narratives, its effect is much less striking when set forth en bloc in a single half-column of print than when the facts slowly evolve before your own eyes,
# 2025-06-08 14:19:02.409 | INFO     | __main__:generate_long:413 - Generating sentence 2/2 of sample 1/1
#   2%|▋                                       | 146/7945 [00:02<02:17, 56.82it/s]
# 2025-06-08 14:19:05.155 | INFO     | __main__:generate_long:451 - Generated 148 tokens in 2.75 seconds, 53.91 tokens/sec
# 2025-06-08 14:19:05.155 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 46.37 GB/s
# 2025-06-08 14:19:05.156 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.86 GB
# 2025-06-08 14:19:05.157 | INFO     | __main__:main:640 - Sampled text: and the mystery clears gradually away as each new discovery furnishes a step which leads on to the complete truth.
# 2025-06-08 14:19:05.159 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:19:05.159 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:19:21.534 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:19:21.535 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:19:22.800 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 886784]), equivalent to 20.11 seconds from 433 features, features/second: 21.53
# 2025-06-08 14:19:22.819 | INFO     | __main__:main:119 - Saved audio to temp/2.wav
# Processing text: At the time the circumstances made a deep impression upon me, and the lapse of two years has hardly served to weaken the effect.
# 2025-06-08 14:19:28.024 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:19:28.300 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:19:36.315 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:19:38.766 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:19:38.766 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:19:38.767 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:19:39.409 | INFO     | __main__:main:607 - Time to load model: 11.38 seconds
# 2025-06-08 14:19:39.418 | INFO     | __main__:generate_long:395 - Encoded text: At the time the circumstances made a deep impression upon me, and the lapse of two years has hardly served to weaken the effect.
# 2025-06-08 14:19:39.419 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▋                                       | 136/7941 [00:12<11:42, 11.10it/s]
# 2025-06-08 14:19:52.306 | INFO     | __main__:generate_long:442 - Compilation time: 12.89 seconds
# 2025-06-08 14:19:52.306 | INFO     | __main__:generate_long:451 - Generated 138 tokens in 12.89 seconds, 10.71 tokens/sec
# 2025-06-08 14:19:52.306 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 9.21 GB/s
# 2025-06-08 14:19:52.306 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:19:52.316 | INFO     | __main__:main:640 - Sampled text: At the time the circumstances made a deep impression upon me, and the lapse of two years has hardly served to weaken the effect.
# 2025-06-08 14:19:52.317 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:19:52.317 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:20:03.409 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:20:03.410 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:20:04.214 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 280576]), equivalent to 6.36 seconds from 137 features, features/second: 21.53
# 2025-06-08 14:20:04.220 | INFO     | __main__:main:119 - Saved audio to temp/3.wav
# Processing text: It was in the summer of ’89, not long after my marriage, that the events occurred which I am now about to summarise.
# 2025-06-08 14:20:08.240 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:20:08.430 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:20:14.916 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:20:17.401 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:20:17.402 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:20:17.402 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:20:18.004 | INFO     | __main__:main:607 - Time to load model: 9.76 seconds
# 2025-06-08 14:20:18.018 | INFO     | __main__:generate_long:395 - Encoded text: It was in the summer of '89, not long after my marriage, that the events occurred which I am now about to summarise.
# 2025-06-08 14:20:18.019 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▌                                       | 123/7938 [00:11<12:24, 10.50it/s]
# 2025-06-08 14:20:30.307 | INFO     | __main__:generate_long:442 - Compilation time: 12.29 seconds
# 2025-06-08 14:20:30.307 | INFO     | __main__:generate_long:451 - Generated 125 tokens in 12.29 seconds, 10.17 tokens/sec
# 2025-06-08 14:20:30.307 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 8.75 GB/s
# 2025-06-08 14:20:30.308 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:20:30.318 | INFO     | __main__:main:640 - Sampled text: It was in the summer of '89, not long after my marriage, that the events occurred which I am now about to summarise.
# 2025-06-08 14:20:30.319 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:20:30.319 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:20:41.501 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:20:41.502 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:20:42.292 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 253952]), equivalent to 5.76 seconds from 124 features, features/second: 21.53
# 2025-06-08 14:20:42.297 | INFO     | __main__:main:119 - Saved audio to temp/4.wav
# Processing text: I had returned to civil practice and had finally abandoned Holmes in his Baker Street rooms, although I continually visited him and occasionally even persuaded him to forgo his Bohemian habits so far as to come and visit us.
# 2025-06-08 14:20:46.280 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:20:46.476 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:20:52.730 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:20:53.970 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:20:53.970 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:20:53.970 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:20:54.600 | INFO     | __main__:main:607 - Time to load model: 8.32 seconds
# 2025-06-08 14:20:54.611 | INFO     | __main__:generate_long:395 - Encoded text: I had returned to civil practice and had finally abandoned Holmes in his Baker Street rooms, although I continually visited him and occasionally even persuaded him to forgo his Bohemian habits so far as to come and visit us.
# 2025-06-08 14:20:54.611 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   3%|█▎                                      | 255/7923 [00:13<06:52, 18.58it/s]
# 2025-06-08 14:21:08.901 | INFO     | __main__:generate_long:442 - Compilation time: 14.29 seconds
# 2025-06-08 14:21:08.901 | INFO     | __main__:generate_long:451 - Generated 257 tokens in 14.29 seconds, 17.99 tokens/sec
# 2025-06-08 14:21:08.901 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 15.47 GB/s
# 2025-06-08 14:21:08.901 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:21:08.913 | INFO     | __main__:main:640 - Sampled text: I had returned to civil practice and had finally abandoned Holmes in his Baker Street rooms, although I continually visited him and occasionally even persuaded him to forgo his Bohemian habits so far as to come and visit us.
# 2025-06-08 14:21:08.914 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:21:08.914 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:21:20.009 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:21:20.010 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:21:20.822 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 524288]), equivalent to 11.89 seconds from 256 features, features/second: 21.53
# 2025-06-08 14:21:20.838 | INFO     | __main__:main:119 - Saved audio to temp/5.wav
# Processing text: My practice had steadily increased, and as I happened to live at no very great distance from Paddington Station, I got a few patients from among the officials.
# 2025-06-08 14:21:24.715 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:21:24.879 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:21:31.122 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:21:33.491 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:21:33.492 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:21:33.492 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:21:34.210 | INFO     | __main__:main:607 - Time to load model: 9.49 seconds
# 2025-06-08 14:21:34.219 | INFO     | __main__:generate_long:395 - Encoded text: My practice had steadily increased, and as I happened to live at no very great distance from Paddington Station, I got a few patients from among the officials.
# 2025-06-08 14:21:34.219 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▊                                       | 170/7935 [00:12<09:30, 13.60it/s]
# 2025-06-08 14:21:47.298 | INFO     | __main__:generate_long:442 - Compilation time: 13.08 seconds
# 2025-06-08 14:21:47.298 | INFO     | __main__:generate_long:451 - Generated 172 tokens in 13.08 seconds, 13.15 tokens/sec
# 2025-06-08 14:21:47.298 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 11.31 GB/s
# 2025-06-08 14:21:47.298 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:21:47.306 | INFO     | __main__:main:640 - Sampled text: My practice had steadily increased, and as I happened to live at no very great distance from Paddington Station, I got a few patients from among the officials.
# 2025-06-08 14:21:47.307 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:21:47.307 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:21:58.892 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:21:58.892 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:21:59.632 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 350208]), equivalent to 7.94 seconds from 171 features, features/second: 21.53
# 2025-06-08 14:21:59.653 | INFO     | __main__:main:119 - Saved audio to temp/6.wav
# Processing text: One of these, whom I had cured of a painful and lingering disease, was never weary of advertising my virtues and of endeavouring to send me on every sufferer over whom he might have any influence.
# 2025-06-08 14:22:03.932 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:22:04.123 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:22:11.093 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:22:13.537 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:22:13.537 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:22:13.537 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:22:14.192 | INFO     | __main__:main:607 - Time to load model: 10.26 seconds
# 2025-06-08 14:22:14.203 | INFO     | __main__:generate_long:395 - Encoded text: One of these, whom I had cured of a painful and lingering disease, was never weary of advertising my virtues and of endeavouring to send me on every sufferer over whom he might have any influence.
# 2025-06-08 14:22:14.203 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   3%|█▏                                      | 225/7926 [00:16<09:37, 13.34it/s]
# 2025-06-08 14:22:31.844 | INFO     | __main__:generate_long:442 - Compilation time: 17.64 seconds
# 2025-06-08 14:22:31.845 | INFO     | __main__:generate_long:451 - Generated 227 tokens in 17.64 seconds, 12.87 tokens/sec
# 2025-06-08 14:22:31.845 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 11.07 GB/s
# 2025-06-08 14:22:31.845 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:22:31.854 | INFO     | __main__:main:640 - Sampled text: One of these, whom I had cured of a painful and lingering disease, was never weary of advertising my virtues and of endeavouring to send me on every sufferer over whom he might have any influence.
# 2025-06-08 14:22:31.855 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:22:31.855 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:22:44.574 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:22:44.575 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:22:45.651 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 462848]), equivalent to 10.50 seconds from 226 features, features/second: 21.53
# 2025-06-08 14:22:45.666 | INFO     | __main__:main:119 - Saved audio to temp/7.wav
# Processing text: One morning, at a little before seven o’clock, I was awakened by the maid tapping at the door to announce that two men had come from Paddington and were waiting in the consulting-room.
# 2025-06-08 14:22:50.020 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:22:50.219 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:22:57.819 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:23:00.491 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:23:00.491 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:23:00.491 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:23:01.162 | INFO     | __main__:main:607 - Time to load model: 11.14 seconds
# 2025-06-08 14:23:01.171 | INFO     | __main__:generate_long:395 - Encoded text: One morning, at a little before seven o'clock, I was awakened by the maid tapping at the door to announce that two men had come from Paddington and were waiting in the consulting-room.
# 2025-06-08 14:23:01.171 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▉                                       | 196/7926 [00:13<09:04, 14.20it/s]
# 2025-06-08 14:23:15.622 | INFO     | __main__:generate_long:442 - Compilation time: 14.45 seconds
# 2025-06-08 14:23:15.622 | INFO     | __main__:generate_long:451 - Generated 198 tokens in 14.45 seconds, 13.70 tokens/sec
# 2025-06-08 14:23:15.622 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 11.79 GB/s
# 2025-06-08 14:23:15.622 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:23:15.632 | INFO     | __main__:main:640 - Sampled text: One morning, at a little before seven o'clock, I was awakened by the maid tapping at the door to announce that two men had come from Paddington and were waiting in the consulting-room.
# 2025-06-08 14:23:15.633 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:23:15.634 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:23:28.466 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:23:28.467 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:23:29.392 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 403456]), equivalent to 9.15 seconds from 197 features, features/second: 21.53
# 2025-06-08 14:23:29.400 | INFO     | __main__:main:119 - Saved audio to temp/8.wav
# Processing text: I dressed hurriedly, for I knew by experience that railway cases were seldom trivial, and hastened downstairs.
# 2025-06-08 14:23:33.839 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:23:34.054 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:23:41.163 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:23:43.809 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:23:43.810 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:23:43.810 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:23:44.532 | INFO     | __main__:main:607 - Time to load model: 10.69 seconds
# 2025-06-08 14:23:44.541 | INFO     | __main__:generate_long:395 - Encoded text: I dressed hurriedly, for I knew by experience that railway cases were seldom trivial, and hastened downstairs.
# 2025-06-08 14:23:44.542 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▋                                       | 133/7945 [00:13<12:48, 10.17it/s]
# 2025-06-08 14:23:58.238 | INFO     | __main__:generate_long:442 - Compilation time: 13.70 seconds
# 2025-06-08 14:23:58.238 | INFO     | __main__:generate_long:451 - Generated 135 tokens in 13.70 seconds, 9.86 tokens/sec
# 2025-06-08 14:23:58.238 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 8.48 GB/s
# 2025-06-08 14:23:58.239 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:23:58.250 | INFO     | __main__:main:640 - Sampled text: I dressed hurriedly, for I knew by experience that railway cases were seldom trivial, and hastened downstairs.
# 2025-06-08 14:23:58.251 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:23:58.251 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:24:10.451 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:24:10.451 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:24:11.248 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 274432]), equivalent to 6.22 seconds from 134 features, features/second: 21.53
# 2025-06-08 14:24:11.254 | INFO     | __main__:main:119 - Saved audio to temp/9.wav
# Processing text: As I descended, my old ally, the guard, came out of the room and closed the door tightly behind him.
# 2025-06-08 14:24:15.431 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:24:15.639 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:24:22.848 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:24:25.234 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:24:25.234 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:24:25.234 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:24:25.927 | INFO     | __main__:main:607 - Time to load model: 10.50 seconds
# 2025-06-08 14:24:25.938 | INFO     | __main__:generate_long:395 - Encoded text: As I descended, my old ally, the guard, came out of the room and closed the door tightly behind him.
# 2025-06-08 14:24:25.939 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   1%|▌                                       | 112/7943 [00:13<15:14,  8.56it/s]
# 2025-06-08 14:24:39.734 | INFO     | __main__:generate_long:442 - Compilation time: 13.79 seconds
# 2025-06-08 14:24:39.734 | INFO     | __main__:generate_long:451 - Generated 114 tokens in 13.80 seconds, 8.26 tokens/sec
# 2025-06-08 14:24:39.734 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 7.11 GB/s
# 2025-06-08 14:24:39.735 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:24:39.746 | INFO     | __main__:main:640 - Sampled text: As I descended, my old ally, the guard, came out of the room and closed the door tightly behind him.
# 2025-06-08 14:24:39.747 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:24:39.747 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:24:52.427 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:24:52.428 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:24:53.176 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 231424]), equivalent to 5.25 seconds from 113 features, features/second: 21.53
# 2025-06-08 14:24:53.180 | INFO     | __main__:main:119 - Saved audio to temp/10.wav
# Processing text: \I’ve got him here,\ he whispered, jerking his thumb over his shoulder; \he’s all right.\
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:25:04.601 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:25:04.601 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:25:05.378 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 231424]), equivalent to 5.25 seconds from 113 features, features/second: 21.53
# 2025-06-08 14:25:05.383 | INFO     | __main__:main:119 - Saved audio to temp/11.wav
# Processing text: \What is it, then?\
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:25:16.277 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:25:16.278 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:25:16.959 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 231424]), equivalent to 5.25 seconds from 113 features, features/second: 21.53
# 2025-06-08 14:25:16.965 | INFO     | __main__:main:119 - Saved audio to temp/12.wav
# Processing text: I asked, for his manner suggested that it was some strange creature which he had caged up in my room.
# 2025-06-08 14:25:20.962 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:25:21.149 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:25:27.467 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:25:29.967 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:25:29.967 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:25:29.967 | INFO     | __main__:init_model:311 - Compiling function...
# ...
# 2025-06-08 14:49:25.169 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:49:25.169 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:49:25.884 | INFO     | __main__:main:607 - Time to load model: 10.65 seconds
# 2025-06-08 14:49:25.897 | INFO     | __main__:generate_long:395 - Encoded text: Years, it had been years!
# 2025-06-08 14:49:25.897 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   0%|▏                                        | 35/7960 [00:13<52:41,  2.51it/s]
# 2025-06-08 14:49:40.583 | INFO     | __main__:generate_long:442 - Compilation time: 14.68 seconds
# 2025-06-08 14:49:40.583 | INFO     | __main__:generate_long:451 - Generated 37 tokens in 14.69 seconds, 2.52 tokens/sec
# 2025-06-08 14:49:40.583 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 2.17 GB/s
# 2025-06-08 14:49:40.583 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:49:40.594 | INFO     | __main__:main:640 - Sampled text: Years, it had been years!
# 2025-06-08 14:49:40.595 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:49:40.595 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:49:52.517 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:49:52.517 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:49:53.209 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 73728]), equivalent to 1.67 seconds from 36 features, features/second: 21.53
# 2025-06-08 14:49:53.215 | INFO     | __main__:main:119 - Saved audio to temp/21.wav
# Processing text: And yet, there she was, waving, her laughter already reaching me like the brightest melody.
# 2025-06-08 14:49:58.004 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:49:58.236 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:50:06.577 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:50:07.899 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:50:07.899 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:50:07.899 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:50:08.558 | INFO     | __main__:main:607 - Time to load model: 10.55 seconds
# 2025-06-08 14:50:08.567 | INFO     | __main__:generate_long:395 - Encoded text: And yet, there she was, waving, her laughter already reaching me like the brightest melody.
# 2025-06-08 14:50:08.567 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   1%|▌                                        | 98/7948 [00:12<16:11,  8.08it/s]
# 2025-06-08 14:50:21.254 | INFO     | __main__:generate_long:442 - Compilation time: 12.69 seconds
# 2025-06-08 14:50:21.255 | INFO     | __main__:generate_long:451 - Generated 100 tokens in 12.69 seconds, 7.88 tokens/sec
# 2025-06-08 14:50:21.255 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 6.78 GB/s
# 2025-06-08 14:50:21.256 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:50:21.267 | INFO     | __main__:main:640 - Sampled text: And yet, there she was, waving, her laughter already reaching me like the brightest melody.
# 2025-06-08 14:50:21.269 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:50:21.269 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:50:33.518 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:50:33.519 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:50:34.235 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 202752]), equivalent to 4.60 seconds from 99 features, features/second: 21.53
# 2025-06-08 14:50:34.241 | INFO     | __main__:main:119 - Saved audio to temp/22.wav
# Processing text: Suddenly, all the weariness of the journey, all the little anxieties that had been nibbling at me, just vanished, poof!
# 2025-06-08 14:50:38.372 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:50:38.568 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:50:45.682 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:50:48.081 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:50:48.081 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:50:48.081 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:50:48.742 | INFO     | __main__:main:607 - Time to load model: 10.37 seconds
# 2025-06-08 14:50:48.753 | INFO     | __main__:generate_long:395 - Encoded text: Suddenly, all the weariness of the journey, all the little anxieties that had been nibbling at me, just vanished, poof!
# 2025-06-08 14:50:48.754 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▋                                       | 139/7938 [00:13<12:21, 10.52it/s]
# 2025-06-08 14:51:02.618 | INFO     | __main__:generate_long:442 - Compilation time: 13.86 seconds
# 2025-06-08 14:51:02.618 | INFO     | __main__:generate_long:451 - Generated 141 tokens in 13.86 seconds, 10.17 tokens/sec
# 2025-06-08 14:51:02.618 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 8.75 GB/s
# 2025-06-08 14:51:02.618 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:51:02.630 | INFO     | __main__:main:640 - Sampled text: Suddenly, all the weariness of the journey, all the little anxieties that had been nibbling at me, just vanished, poof!
# 2025-06-08 14:51:02.631 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:51:02.631 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:51:14.702 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:51:14.702 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:51:15.452 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 286720]), equivalent to 6.50 seconds from 140 features, features/second: 21.53
# 2025-06-08 14:51:15.457 | INFO     | __main__:main:119 - Saved audio to temp/23.wav
# Processing text: Replaced by this bubbling, infectious joy that made me want to leap and spin and shout to the whole world.
# 2025-06-08 14:51:19.806 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:51:20.019 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:51:26.892 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:51:29.256 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:51:29.257 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:51:29.257 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:51:29.896 | INFO     | __main__:main:607 - Time to load model: 10.09 seconds
# 2025-06-08 14:51:29.905 | INFO     | __main__:generate_long:395 - Encoded text: Replaced by this bubbling, infectious joy that made me want to leap and spin and shout to the whole world.
# 2025-06-08 14:51:29.905 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▋                                       | 127/7943 [00:13<13:20,  9.76it/s]
# 2025-06-08 14:51:43.468 | INFO     | __main__:generate_long:442 - Compilation time: 13.56 seconds
# 2025-06-08 14:51:43.468 | INFO     | __main__:generate_long:451 - Generated 129 tokens in 13.56 seconds, 9.51 tokens/sec
# 2025-06-08 14:51:43.468 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 8.18 GB/s
# 2025-06-08 14:51:43.468 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:51:43.478 | INFO     | __main__:main:640 - Sampled text: Replaced by this bubbling, infectious joy that made me want to leap and spin and shout to the whole world.
# 2025-06-08 14:51:43.479 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:51:43.479 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:51:55.522 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:51:55.522 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:51:56.253 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 262144]), equivalent to 5.94 seconds from 128 features, features/second: 21.53
# 2025-06-08 14:51:56.259 | INFO     | __main__:main:119 - Saved audio to temp/24.wav
# Processing text: Everything felt lighter, brighter, like the sun had decided to shine just for us in that perfect, unforgettable second.
# 2025-06-08 14:52:00.696 | INFO     | __main__:main:593 - Loading model ...
# 2025-06-08 14:52:00.926 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:396 - Loading model from checkpoints/openaudio-s1-mini, config: DualARModelArgs(model_type='dual_ar', vocab_size=155776, n_layer=28, n_head=16, dim=1024, intermediate_size=3072, n_local_heads=8, head_dim=128, rope_base=1000000, norm_eps=1e-06, max_seq_len=8192, dropout=0.0, tie_word_embeddings=False, attention_qkv_bias=False, attention_o_bias=False, attention_qk_norm=True, codebook_size=4096, num_codebooks=10, use_gradient_checkpointing=True, initializer_range=0.03125, is_reward_model=False, scale_codebook_embeddings=True, n_fast_layer=4, fast_dim=1024, fast_n_head=16, fast_n_local_heads=8, fast_head_dim=64, fast_intermediate_size=3072, fast_attention_qkv_bias=False, fast_attention_qk_norm=False, fast_attention_o_bias=False)
# 2025-06-08 14:52:08.282 | INFO     | fish_speech.models.text2semantic.llama:from_pretrained:462 - Loaded weights with error: <All keys matched successfully>
# 2025-06-08 14:52:10.718 | INFO     | __main__:init_model:302 - Restored model from checkpoint
# 2025-06-08 14:52:10.718 | INFO     | __main__:init_model:306 - Using DualARTransformer
# 2025-06-08 14:52:10.718 | INFO     | __main__:init_model:311 - Compiling function...
# 2025-06-08 14:52:11.500 | INFO     | __main__:main:607 - Time to load model: 10.80 seconds
# 2025-06-08 14:52:11.512 | INFO     | __main__:generate_long:395 - Encoded text: Everything felt lighter, brighter, like the sun had decided to shine just for us in that perfect, unforgettable second.
# 2025-06-08 14:52:11.512 | INFO     | __main__:generate_long:413 - Generating sentence 1/1 of sample 1/1
#   2%|▋                                       | 148/7944 [00:13<11:32, 11.25it/s]
# 2025-06-08 14:52:25.446 | INFO     | __main__:generate_long:442 - Compilation time: 13.93 seconds
# 2025-06-08 14:52:25.446 | INFO     | __main__:generate_long:451 - Generated 150 tokens in 13.93 seconds, 10.77 tokens/sec
# 2025-06-08 14:52:25.446 | INFO     | __main__:generate_long:454 - Bandwidth achieved: 9.26 GB/s
# 2025-06-08 14:52:25.446 | INFO     | __main__:generate_long:459 - GPU Memory used: 2.84 GB
# 2025-06-08 14:52:25.457 | INFO     | __main__:main:640 - Sampled text: Everything felt lighter, brighter, like the sun had decided to shine just for us in that perfect, unforgettable second.
# 2025-06-08 14:52:25.457 | INFO     | __main__:main:645 - Saved codes to temp/codes_0.npy
# 2025-06-08 14:52:25.458 | INFO     | __main__:main:646 - Next sample
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-08 14:52:37.870 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-08 14:52:37.870 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# 2025-06-08 14:52:38.647 | INFO     | __main__:main:112 - Generated audio of shape torch.Size([1, 1, 305152]), equivalent to 6.92 seconds from 149 features, features/second: 21.53
# 2025-06-08 14:52:38.667 | INFO     | __main__:main:119 - Saved audio to temp/25.wav
# sox  temp/0.wav temp/1.wav temp/2.wav temp/3.wav temp/4.wav temp/5.wav temp/6.wav temp/7.wav temp/8.wav temp/9.wav temp/10.wav temp/11.wav temp/12.wav temp/13.wav temp/14.wav temp/15.wav temp/16.wav temp/17.wav temp/18.wav temp/19.wav temp/20.wav temp/21.wav temp/22.wav temp/23.wav temp/24.wav temp/25.wav ../outputs/fish-speech/3.txt.wav

# %% [markdown]
# ### 3. Generate speech from semantic tokens: / 从语义 token 生成人声:

# %%
from IPython.display import Audio, display
audio = Audio(filename="fake.wav")
display(audio)
# Out:
# /home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# 2025-06-06 21:11:38.665 | INFO     | __main__:load_model:46 - Loaded model: <All keys matched successfully>
# 2025-06-06 21:11:38.666 | INFO     | __main__:main:100 - Processing precomputed indices from temp/codes_0.npy
# Traceback (most recent call last):
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/inference.py", line 123, in <module>
#     main()
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/inference.py", line 109, in main
#     fake_audios, audio_lengths = model.decode(indices, indices_lens)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/modded_dac.py", line 928, in decode
#     return self.decoder(z), audio_lengths
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/modded_dac.py", line 801, in forward
#     return self.model(x)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py", line 240, in forward
#     input = module(input)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/modded_dac.py", line 757, in forward
#     return self.block(x)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py", line 240, in forward
#     input = module(input)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/modded_dac.py", line 613, in forward
#     y = self.block(x)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/container.py", line 240, in forward
#     input = module(input)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/fish_speech/models/dac/modded_dac.py", line 552, in forward
#     return self.conv(x).contiguous()
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 375, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/home/eingerman/Projects/TTS/TTSEval/fish-speech/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 370, in _conv_forward
#     return F.conv1d(
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
